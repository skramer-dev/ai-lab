# %% [markdown]
# # Data Augmentation Pipeline

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image as image
import skimage.io
from joblib import Parallel, delayed
from skimage import transform, morphology, color
import cv2
import tensorflow as tf

# %% [markdown]
# #### Konstanten

# %%
DATA_PATH = "../../Pokemon-data/"
# Max 4 Chars
SUPPORTED_TYPES_LIST = [".png",".jpg","jpeg"]

# %% [markdown]
# #### Augmentation Funktionen

# %%
## Color Augmentation
def increase_red_color(img, increase):
    """Increase red component of an image
        img: input image
        increase: summand for the r channel values
    """
    for i in img:
        for j in i:
            if not (j[0] >= (255-increase)):
                j[0] += increase
            if not (j[1] <= increase):
                j[1] -= increase
            if not (j[2] <= increase):
                j[2] -= increase
    return img

# Increase green component of an image
def increase_green_color(img, increase):
    # Green is to agressive
    for i in img:
        for j in i:
            if not (j[1] >= (255-increase)):
                j[1] += increase
            if not (j[0] <= increase):
                j[0] -= increase
            if not (j[2] <= increase):
                j[2] -= increase
    return img


# Increase blue component of an image
def increase_blue_color(img, increase):
    for i in img:
        for j in i:
            if not (j[2] >= (255-increase)):
                j[2] += increase
            if not (j[1] <= increase):
                j[1] -= increase
            if not (j[0] <= increase):
                j[0] -= increase
    return img

# Increase random color component of an image
def increase_random_color(img):
    img = img.copy()
    np.random.seed()
    increase = np.random.randint(25, 65)
    np.random.seed()
    color = np.random.randint(0, 3)

    if color == 0:
        return increase_red_color(img, increase)
    if color == 1:
        return increase_green_color(img, increase)
    if color == 2:
        return increase_blue_color(img, increase)

# Shouldn't be combined with random image
def img_dilation(img):
    return morphology.dilation(img)

## Positional Augmentation
def random_rotation(img):
    np.random.seed()
    rotation_count = np.random.randint(0, 6)
    img = img.astype(np.uint8)
    return transform.rotate(img,(90*rotation_count))

def img_flip(img):
    return img[:,::-1,:]

def random_crop(img):
    np.random.seed()
    rand_size_factor_x = np.random.randint(0, 3)
    np.random.seed()
    rand_size_factor_y = np.random.randint(0,2)
    img = img[25*rand_size_factor_x:175+(rand_size_factor_y*15), 25*rand_size_factor_x:175+(rand_size_factor_y*15),:]
    img = cv2.resize(img, (224,224))
    return img

# %% [markdown]
# #### Pipeline Hilfsfunktionen

# %%
# Helper functions
def get_all_images_for_label(label):
    return os.listdir(f"{DATA_PATH}/{label}")

def get_all_labels(data_path):
    return os.listdir(f"{data_path}")

def apply_augmentations(augmentation_functions,probability_list, img, target_shape):
    img = cv2.resize(img, target_shape)
    img = img[:,:,:3]
    for index, augmentation in enumerate(augmentation_functions):
        np.random.seed()
        if np.random.uniform(0,1) < probability_list[index]:
            img = augmentation(img)
    return img

def create_dir_structure(output_path, labels):
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    for label in labels:
        label_path = f"{output_path}/{label}"
        if not os.path.exists(label_path):
            os.mkdir(label_path)

def load_image(path):
    return skimage.io.imread(path)

def save_result_to_folder(image_data, output_path, label, pkm_image_name):
    skimage.io.imsave(f"{output_path}{label}/{pkm_image_name}", image_data)

def create_path_list(data_path,labels):
    path_list = []
    for label in labels:
        for pkm_image in get_all_images_for_label(label):
            path_list.append(f"{data_path}{label}/{pkm_image}")
    return path_list

def run_pipeline_for_path(path, output_path, probability_list, augmentation_functions, target_shape):
    if path[-4:] in SUPPORTED_TYPES_LIST:
        img = load_image(path)
        if len(img.shape) == 3: 
            synth_image = apply_augmentations(augmentation_functions=augmentation_functions,probability_list=probability_list, img=img, target_shape=target_shape)
            parts = str(path).split("/")
            save_result_to_folder(synth_image, output_path, parts[3], parts[4])

# %% [markdown]
# #### Parallelisierte Pipeline

# %%
# Pipeline
# Possible extension -> Probability list
def augmentation_pipeline(augmentation_functions, probability_list, data_path, output_path, target_shape=(224,224), num_workers=5):
    labels = get_all_labels(data_path)
    path_list = create_path_list(data_path,labels)
    create_dir_structure(output_path, labels)
    _ = Parallel(n_jobs=num_workers)(delayed(run_pipeline_for_path)(path=path, output_path=output_path,
        probability_list=probability_list, 
        augmentation_functions=augmentation_functions,
        target_shape=target_shape) for path in path_list)

# %% [markdown]
# #### Pipeline 1: Wenig
#
# - increase random color takes long

# %%
augmentation_pipeline([img_flip, increase_random_color],[0.5,0.7], DATA_PATH, "../../pipeline_one/",target_shape=(224,224), num_workers=15)

# %% [markdown]
# #### Pipeline 2: Mittel

# %%
augmentation_pipeline([increase_random_color,random_rotation,random_crop],[0.10,0.20,0.40], DATA_PATH, "../../pipeline_two/",target_shape=(224,224), num_workers=15)

# %% [markdown]
# #### Pipeline 3: Viel

# %%
augmentation_pipeline([img_dilation,img_flip,random_rotation,random_crop],[0.2,0.75,0.60,0.35], DATA_PATH, "../../pipeline_three/",target_shape=(224,224), num_workers=15)

# %% [markdown]
# #### Testbereich

# %%
labels = get_all_labels(data_path=DATA_PATH)

# %%
elements = os.listdir(f"{DATA_PATH}/{labels[0]}")
img = mpimg.imread(f"{DATA_PATH}/{labels[0]}/{elements[9]}")
imgplot = plt.imshow(img)
print(img.shape)
print(img.dtype)
plt.show()
# Out:
# (210, 218, 3)
# uint8

# %%
elements = os.listdir(f"{DATA_PATH}/{labels[0]}")
img = skimage.io.imread(f"../../Pokemon-data/Bulbasaur/00000000.png")
imgplot = plt.imshow(img)
print(img.shape)
print(img.dtype)
plt.show()
# Out:
# (900, 900, 4)
# uint8

# %%
img = skimage.io.imread(f"../../Pokemon-data/Bulbasaur/00000000.png")
img = cv2.resize(img, (224,224))
img = img[:,:,:3]
print(img.shape)
img = random_crop(img)
plt.imshow(img)
# Out:
# (224, 224, 3)

# %%
img = load_image(f"{DATA_PATH}/{labels[0]}/{elements[9]}")
img = img.astype(np.uint8)
print(f"Input shape: {img.shape}")
print(f"Removed alpha shape: {img.shape}")

img = img[25:175, 80:230,:]
img = cv2.resize(img, (224,224))
print(f"Applied resize shape: {img.shape}")

img = transform.rotate(img,90.0*np.random.randint(0,6))
img = increase_random_color(img)

img = img_flip(img)
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Input shape: (210, 218, 3)
# Removed alpha shape: (210, 218, 3)
# Applied resize shape: (224, 224, 3)

# %%
# Test some data augmentation techniques
img = load_image(f"{DATA_PATH}/{labels[0]}/{elements[9]}")
img = img.astype(np.uint8)
print(f"Input shape: {img.shape}")
print(f"Removed alpha shape: {img.shape}")
img = cv2.resize(img, (224,224))
print(f"Applied resize shape: {img.shape}")

img = transform.rotate(img,90.0*np.random.randint(0,6))
img = increase_random_color(img)

img = img_flip(img)
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Input shape: (210, 218, 3)
# Removed alpha shape: (210, 218, 3)
# Applied resize shape: (224, 224, 3)

# %%
# Test some data augmentation techniques
img = load_image(f"{DATA_PATH}/{labels[0]}/{elements[9]}")
img = cv2.resize(img, (224,224))
print(img.shape)
img = increase_random_color(img)
img = random_rotation(img)
img = img_flip(img)
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21340/862654852.py in <module>
#       1 # Test some data augmentation techniques
# ----> 2 img = load_image(f"{DATA_PATH}/{labels[0]}/{elements[9]}")
#       3 img = cv2.resize(img, (224,224))
#       4 print(img.shape)
#       5 img = increase_random_color(img)
#
# NameError: name 'elements' is not defined

# %%
labels = get_all_labels(DATA_PATH)
path_list = create_path_list(DATA_PATH,labels)
for path in path_list:
    if path[-4:] in SUPPORTED_TYPES_LIST:
        img = load_image(path)
        img = cv2.resize(img, (224,224))
        if type(img) != "unit8":
            print(img.dtype)
# Out:
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8

# %%
labels = get_all_labels(DATA_PATH)
path_list = create_path_list(DATA_PATH,labels)
for path in path_list:
    if path[-4:] in SUPPORTED_TYPES_LIST:
        img = load_image(path)
        img = cv2.resize(img, (224,224))
        shapetest = img.shape
        if shapetest != (224,224,3):
            
            print(path)
            print(shapetest)
            print(len(img.shape))
# Out:
# ../../Pokemon-data/Alolan Sandslash/Alolan Sandslash.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Alolan Sandslash/AlolanSandslashDuel475.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Alolan Sandslash/asandslashbattle1.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Alolan Sandslash/high_quality_wallpaper_HD_1080_IDS_1158914.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Alolan Sandslash/WV4lqZqCl7.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000000.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000004.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000005.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000009.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000010.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000011.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000012.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000013.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000014.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000016.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000017.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000020.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000021.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000024.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000027.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000028.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Bulbasaur/00000031.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000000.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000003.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000004.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000005.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000008.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000010.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000015.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000016.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000020.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000021.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000022.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000025.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000030.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000031.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000036.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000038.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000040.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000045.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Charmander/00000046.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000005.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000009.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000015.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000017.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000020.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000026.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000031.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000040.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000043.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000045.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000046.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000050.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000051.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000069.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000074.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Mewtwo/00000206.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Onix/a445ddff0c6640a381e2da954f117e88.jpg
# (224, 224)
# 2
# ../../Pokemon-data/Pikachu/00000001.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000010.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000011.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000014.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000015.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000020.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000021.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000023.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000024.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000031.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000035.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000036.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000038.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000043.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000050.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000052.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000058.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000066.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000067.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000069.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Pikachu/00000074.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Seadra/a9e0e66523a5477fb8cb58b57d89af24.jpg
# (224, 224)
# 2
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.34.39 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.34.47 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.00 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.09 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.14 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.37 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.44 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.35.50 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.36.00 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Slowbro/Screen Shot 2019-08-12 at 8.36.17 PM.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000000.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000003.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000005.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000006.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000008.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000009.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000010.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000016.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000017.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000022.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000023.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000024.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000025.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000027.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000031.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000034.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000040.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000043.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000044.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000050.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Squirtle/00000051.png
# (224, 224, 4)
# 3
# ../../Pokemon-data/Venusaur/e20dd0c9dbae4a299b32be5f486e4143.jpg
# (224, 224)
# 2
